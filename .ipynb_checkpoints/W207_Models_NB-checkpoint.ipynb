# %% [markdown]
# #Load Libraries

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.ensemble import ExtraTreesClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from sklearn import preprocessing
from sklearn import metrics
from sklearn.learning_curve import learning_curve

# %% [markdown]
# #Load Data

# %%
training = pd.read_csv('train.csv')
training = training.reindex(np.random.permutation(training.index))

breakpoint = int(0.8 * training.shape[0])

train_data = training.copy()[:breakpoint]
valid_data = training.copy()[breakpoint:]

test_data = pd.read_csv('test.csv')

for col in ['Elevation', 'Slope','Horizontal_Distance_To_Hydrology','Vertical_Distance_To_Hydrology','Horizontal_Distance_To_Roadways','Hillshade_9am','Hillshade_Noon','Hillshade_3pm']:
    train_data[col] = preprocessing.scale(train_data[col].values.astype(float))
    valid_data[col] = preprocessing.scale(valid_data[col].values.astype(float))
    test_data[col] = preprocessing.scale(test_data[col].values.astype(float))

# %% [markdown]
# #Logistic Regression

# %%
features = [label for label in train_data.columns if label not in ['Cover_Type','Id']]
y = train_data['Cover_Type'].values
x = train_data[features].values

valid_y = valid_data['Cover_Type'].values
valid_x = valid_data[features].values

lr = LogisticRegression()
lr.fit(x, y)

pred_valid = lr.predict(valid_x)

print metrics.confusion_matrix(valid_y, pred_valid)
print metrics.classification_report(valid_y, pred_valid)
print metrics.accuracy_score(valid_y, pred_valid)
# Out:
# [[288  91   0   0  28   3  49]
#  [ 66 228   5   2 110  23   5]
#  [  0   3 193  75  18 114   0]
#  [  0   0  36 400   0  21   0]
#  [  9  57  23   0 312  23   0]
#  [  0  12  84  49  46 214   0]
#  [ 56   3   0   0   2   0 376]]
#              precision    recall  f1-score   support
#
#           1       0.69      0.63      0.66       459
#           2       0.58      0.52      0.55       439
#           3       0.57      0.48      0.52       403
#           4       0.76      0.88      0.81       457
#           5       0.60      0.74      0.66       424
#           6       0.54      0.53      0.53       405
#           7       0.87      0.86      0.87       437
#
# avg / total       0.66      0.67      0.66      3024
#
# 0.665013227513

# %% [markdown]
# #Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(x, y)
pred_valid = rf.predict(valid_x)

cf = metrics.confusion_matrix(valid_y, pred_valid)
print "Accuracy: %.2f%%" % (metrics.accuracy_score(valid_y, pred_valid) * 100)

conf_arr = cf.tolist()
norm_conf = []
for i in conf_arr:
    a = 0
    tmp_arr = []
    a = sum(i, 0)
    for j in i:
        if a == 0:
            tmp_arr.append(0)
        else:
            tmp_arr.append(float(j)/float(a))
    norm_conf.append(tmp_arr)
cmap = sns.light_palette('green', as_cmap = True)
fig = plt.figure()
plt.clf()
ax = fig.add_subplot(111)
ax.set_aspect(1)
res = ax.imshow(np.array(norm_conf), cmap=cmap, 
                interpolation='nearest')

width = len(conf_arr)
height = len(conf_arr[0])

for x in xrange(width):
    for y in xrange(height):
        ax.annotate(str(conf_arr[x][y]), xy=(y, x), 
                    horizontalalignment='center',
                    verticalalignment='center',
                    weight='bold')
plt.title('Random Forest Confusion Matrix',weight='bold')
plt.ylabel('Actual Category', style='italic')
plt.xlabel('Predicted Category',style='italic')
items = [1,2,3,4,5,6,7]
plt.xticks(range(width), items)
plt.yticks(range(height), items)
plt.grid(b = None)
# Out:
# Accuracy: 83.56%

# %% [markdown]
# #Choose Number of Estimators

# %%
n = xrange(50,1000,50)
mse_valid = []
accuracy_valid = []
mse_train = []
accuracy_train = []
for i in n:    
    rf = RandomForestClassifier(n_estimators=i,criterion='entropy')
    rf.fit(x, y)
    pred_valid = rf.predict(valid_x)
    pred_y = rf.predict(x)
    
    acc = metrics.accuracy_score(valid_y, pred_valid)
    print "N= %d, Accuracy on Validation: %f" % (i,acc)
    
    accuracy_valid.append(acc)
    mse_valid.append(metrics.mean_squared_error(valid_y, pred_valid))
    accuracy_train.append(metrics.accuracy_score(y, pred_y))
    mse_train.append(metrics.mean_squared_error(y, pred_y))
# Out:
# N= 50, Accuracy: 0.855820
# N= 100, Accuracy: 0.857143
# N= 150, Accuracy: 0.856481
# N= 200, Accuracy: 0.862103
# N= 250, Accuracy: 0.858466
# N= 300, Accuracy: 0.860780
# N= 350, Accuracy: 0.860780
# N= 400, Accuracy: 0.862434
# N= 450, Accuracy: 0.858466
# N= 500, Accuracy: 0.862765
# N= 550, Accuracy: 0.861442
# N= 600, Accuracy: 0.857474
# N= 650, Accuracy: 0.861111
# N= 700, Accuracy: 0.860780
# N= 750, Accuracy: 0.861772
# N= 800, Accuracy: 0.863095
# N= 850, Accuracy: 0.861111
# N= 900, Accuracy: 0.862103
# N= 950, Accuracy: 0.862103

# %%
df = pd.DataFrame([n, accuracy, mse]).T
df.columns = ['n','accuracy','mse']
sns.lmplot(x = 'n', y = 'accuracy',data = df, lowess =True)

plt.plot(n, accuracy, 'r-')
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy on Validation Data')
plt.title('Accuracy vs. Number of Estimators');

# %%
df2 = pd.DataFrame([n, accuracy, mse]).T
df2.columns = ['n','accuracy','mse']
sns.lmplot(x = 'n', y = 'mse',data = df2, lowess =True)
plt.plot(n, mse, 'r-')
plt.xlabel('Number of Estimators')
plt.ylabel('MSE on Validation Data')
plt.title('MSE vs. Number of Estimators');

train_sizes_abs, train_scores, test_scores = learning_curve(RandomForestClassifier(n_estimators=800, criterion='entropy'),x, y, cv = 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-c5ba982936f2> in <module>()
#       8
#       9 train_sizes_abs, train_scores, test_scores = learning_curve(RandomForestClassifier(n_estimators=800, criterion='entropy'),
# ---> 10                                                             x, y, cv = 3)
#
# /home/nate_black/anaconda/lib/python2.7/site-packages/sklearn/learning_curve.pyc in learning_curve(estimator, X, y, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose)
#     102                          "to exploit incremental learning")
#     103
# --> 104     X, y = indexable(X, y)
#     105     # Make a list since we will be iterating multiple times over the folds
#     106     cv = list(_check_cv(cv, X, y, classifier=is_classifier(estimator)))
#
# /home/nate_black/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in indexable(*iterables)
#     197         else:
#     198             result.append(np.array(X))
# --> 199     check_consistent_length(*result)
#     200     return result
#     201
#
# /home/nate_black/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     169     """
#     170
# --> 171     uniques = np.unique([_num_samples(X) for X in arrays if X is not None])
#     172     if len(uniques) > 1:
#     173         raise ValueError("Found arrays with inconsistent numbers of samples: "
#
# /home/nate_black/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _num_samples(x)
#     118         if len(x.shape) == 0:
#     119             raise TypeError("Singleton array %r cannot be considered"
# --> 120                             " a valid collection." % x)
#     121         return x.shape[0]
#     122     else:
#
# TypeError: Singleton array array(6) cannot be considered a valid collection.

# %%
plt.plot(train_sizes_abs, train_scores)
test_scores
# Out:
# array([[ 0.72018159,  0.73719008,  0.74824308,  0.74803475,  0.72693422],
#        [ 0.79075526,  0.79421488,  0.81727987,  0.79685561,  0.80513033],
#        [ 0.81923236,  0.81487603,  0.83794957,  0.82498966,  0.82829954],
#        [ 0.84110607,  0.8285124 ,  0.85448532,  0.83864295,  0.83988415],
#        [ 0.85142385,  0.84090909,  0.85655229,  0.84898635,  0.85105503]])
